# %% [markdown]
# **1. Data Exploration**

# %%
import pandas as pd

# %%
df_bookings = pd.read_csv('datasets/fact_bookings.csv')

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
 df_bookings.booking_platform.value_counts().plot(marker = 'o',grid = True)
# Out:
# <Axes: xlabel='booking_platform'>

# %%
 df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
 df_bookings.revenue_generated.min(),  df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
df_date = pd.read_csv('datasets/dim_date.csv')
df_hotels =  pd.read_csv('datasets/dim_hotels.csv')
df_rooms = pd.read_csv('datasets/dim_rooms.csv')
df_agg_bookings = pd.read_csv('datasets/fact_aggregated_bookings.csv')

# %%
df_date.shape
# Out:
# (92, 4)

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_date.day_type.unique()
# Out:
# array(['weekend', 'weekeday'], dtype=object)

# %%
df_date.day_type.value_counts()
# Out:
# day_type
# weekeday    65
# weekend     27
# Name: count, dtype: int64

# %%
df_date.describe()
# Out:
#              date  mmm yy week no  day_type
# count          92      92      92        92
# unique         92       3      14         2
# top     01-May-22  May 22    W 19  weekeday
# freq            1      31       7        65

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.city.unique()
# Out:
# array(['Delhi', 'Mumbai', 'Hyderabad', 'Bangalore'], dtype=object)

# %%
df_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <Axes: ylabel='city'>

# %%
df_hotels.describe(include = ['object'])
# Out:
#        property_name category    city
# count             25       25      25
# unique             7        2       4
# top     Atliq Grands   Luxury  Mumbai
# freq               4       16       8

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_rooms.room_class.value_counts()
# Out:
# room_class
# Standard        1
# Elite           1
# Premium         1
# Presidential    1
# Name: count, dtype: int64

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        17558     01-May-22           RT1                   30      19.0
# 4        16558     01-May-22           RT1                   18      19.0

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %%
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %%
df_agg_bookings.groupby("property_id")['successful_bookings'].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
df_agg_bookings[df_agg_bookings.successful_bookings > df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558     01-May-22           RT1                   30      19.0
# 12          16563     01-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560     02-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings[df_agg_bookings['capacity'] == df_agg_bookings['capacity'].max()].property_id.unique()
# Out:
# array([17558])

# %%
df_agg_bookings[df_agg_bookings['capacity'] == df_agg_bookings['capacity'].max()].value_counts().sum()
# Out:
# 92

# %% [markdown]
# **2. DATA CLEANING**

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings = df_bookings[df_bookings.no_guests > 0]

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134578.000000  134578.000000   56679.000000       1.345780e+05
# mean    18061.143315       2.036744       3.619048       1.537804e+04
# std      1093.053454       1.031710       1.234970       9.304015e+04
# min     16558.000000       1.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134578.000000
# mean       12696.011822
# std         6927.841641
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()

# %%
avg , std
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# 294498.50173198653

# %%
lower_limit = avg - 3*std
if lower_limit<0 :
    lower_limit = 0

lower_limit
# Out:
# 0

# %%
df_bookings[(df_bookings['revenue_generated'] > higher_limit) | (df_bookings['revenue_generated'] < lower_limit)]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings = df_bookings[(df_bookings['revenue_generated'] >= lower_limit) & (df_bookings['revenue_generated'] <= higher_limit)]

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134573.000000  134573.000000   56676.000000      134573.000000
# mean    18061.191658       2.036716       3.619045       14915.959776
# std      1093.042273       1.031673       1.234983        6452.676164
# min     16558.000000       1.000000       1.000000        6500.000000
# 25%     17558.000000       1.000000       3.000000        9900.000000
# 50%     17564.000000       2.000000       4.000000       13500.000000
# 75%     18563.000000       2.000000       5.000000       18000.000000
# max     19563.000000       6.000000       5.000000       45220.000000
#
#        revenue_realized
# count     134573.000000
# mean       12695.983585
# std         6927.791692
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_realized.max()
# Out:
# (6500, 45220)

# %%
avg, std = df_bookings.revenue_realized.mean(), df_bookings.revenue_realized.std()
avg ,std
# Out:
# (12695.983585117372, 6927.79169224251)

# %%
higher_limit = avg + 3*std
lower_limit = avg - 3*std
if lower_limit < 0:
    lower_limit = 0

higher_limit, lower_limit
# Out:
# (33479.358661844904, 0)

# %%
df_bookings[(df_bookings['revenue_realized'] > higher_limit ) | (df_bookings['revenue_realized'] < lower_limit )]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings[df_bookings.room_category == 'RT4'].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
avg ,std = df_bookings[df_bookings.room_category == 'RT4'].revenue_realized.mean() , df_bookings[df_bookings.room_category == 'RT4'].revenue_realized.std()
avg + 3*std
# Out:
# 50585.1056709996

# %%
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134573.000000  134573.000000   56676.000000      134573.000000
# mean    18061.191658       2.036716       3.619045       14915.959776
# std      1093.042273       1.031673       1.234983        6452.676164
# min     16558.000000       1.000000       1.000000        6500.000000
# 25%     17558.000000       1.000000       3.000000        9900.000000
# 50%     17564.000000       2.000000       4.000000       13500.000000
# 75%     18563.000000       2.000000       5.000000       18000.000000
# max     19563.000000       6.000000       5.000000       45220.000000
#
#        revenue_realized
# count     134573.000000
# mean       12695.983585
# std         6927.791692
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
#Aggregated_bookings Cleaning

# %%
df_agg_bookings.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings['capacity'].isnull()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561     01-May-22           RT1                   22       NaN
# 14        17562     01-May-22           RT1                   12       NaN

# %%
df_agg_bookings['capacity'] = df_agg_bookings.capacity.fillna(df_agg_bookings.capacity.median())

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %%
df_agg_bookings.loc[[8,15]]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561     01-May-22           RT1                   22      25.0
# 15        17563     01-May-22           RT1                   21      25.0

# %%
df_agg_bookings[df_agg_bookings['successful_bookings'] > df_agg_bookings['capacity']]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558     01-May-22           RT1                   30      19.0
# 12          16563     01-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560     02-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings = df_agg_bookings[df_agg_bookings['successful_bookings'] <= df_agg_bookings['capacity']]

# %%
df_agg_bookings.shape
# Out:
# (9194, 5)

# %% [markdown]
# **3. DATA TRANSFORMATION**

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["successful_bookings"]/df_agg_bookings["capacity"]

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 4        16558     01-May-22           RT1                   18      19.0
# 5        17560     01-May-22           RT1                   28      40.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 4  0.947368
# 5  0.700000

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["occ_pct"].apply(lambda x : round(x*100,2))

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 4        16558     01-May-22           RT1                   18      19.0
# 5        17560     01-May-22           RT1                   28      40.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 4    94.74
# 5    70.00

# %% [markdown]
# **4. INSIGHTS GENERATION**

# %%
#AVERAGE PER ROOM CATEGORY

# %%
df_agg_bookings.groupby('room_category')["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    57.89
# RT2    58.01
# RT3    58.03
# RT4    59.28
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_agg_bookings, df_rooms, left_on = "room_category", right_on = "room_id")
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     01-May-22           RT1                   25      30.0
# 1           19562     01-May-22           RT1                   28      30.0
# 2           19563     01-May-22           RT1                   23      30.0
# 3           16558     01-May-22           RT1                   18      19.0
# 4           17560     01-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9189        16563     31-Jul-22           RT4                   13      18.0
# 9190        16559     31-Jul-22           RT4                   13      18.0
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct room_id    room_class
# ...

# %%
df.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.01
# Premium         58.03
# Presidential    59.28
# Standard        57.89
# Name: occ_pct, dtype: float64

# %%
df.drop(columns = ['room_id'],inplace =True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        16558     01-May-22           RT1                   18      19.0
# 4        17560     01-May-22           RT1                   28      40.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3    94.74   Standard
# 4    70.00   Standard

# %%
df_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df = pd.merge(df, df_hotels, on = "property_id")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        16558     01-May-22           RT1                   18      19.0
# 4        17560     01-May-22           RT1                   28      40.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore
# 3    94.74   Standard   Atliq Grands    Luxury      Delhi
# 4    70.00   Standard     Atliq City  Business     Mumbai

# %%
df.groupby("city")["occ_pct"].mean().round(2).plot(kind = "bar")
# Out:
# <Axes: xlabel='city'>

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df = pd.merge(df, df_date , left_on = "check_in_date" , right_on = "date").drop("date",axis = 1)

# %%
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     01-May-22           RT1                   25      30.0
# 1        19562     01-May-22           RT1                   28      30.0
# 2        19563     01-May-22           RT1                   23      30.0
# 3        16558     01-May-22           RT1                   18      19.0
# 4        17560     01-May-22           RT1                   28      40.0
#
#    occ_pct room_class  property_name  category       city  mmm yy week no  \
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai  May 22    W 19
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore  May 22    W 19
# 2    76.67   Standard   Atliq Palace  Business  Bangalore  May 22    W 19
# 3    94.74   Standard   Atliq Grands    Luxury      Delhi  May 22    W 19
# 4    70.00   Standard     Atliq City  Business     Mumbai  May 22    W 19
#
#   day_type
# 0  weekend
# 1  weekend
# 2  weekend
# 3  weekend
# 4  weekend

# %%
df.groupby("day_type")["occ_pct"].mean().round(2).plot(kind = "bar")
# Out:
# <Axes: xlabel='day_type'>

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df.groupby("mmm yy")["occ_pct"].mean().round(2).plot(
        kind = "pie", 
        autopct="%1.1f%%",   # Show percentage
        #explode=[0.1] * df["mmm yy"].nunique(),  # Explode all slices equally
        explode = (0.1,0.0,0.0),
        shadow=True,
        ylabel = "",
        startangle = 140)
# Out:
# <Axes: >

# %%
df_june_22 = df[df["mmm yy"] == "Jun 22"]

# %%
df_june_22.head()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 3098        16559     01-Jun-22           RT1                   14      30.0
# 3099        18560     01-Jun-22           RT1                   18      30.0
# 3100        19562     01-Jun-22           RT1                   18      30.0
# 3101        19563     01-Jun-22           RT1                   14      30.0
# 3102        17558     01-Jun-22           RT1                    8      19.0
#
#       occ_pct room_class  property_name  category       city  mmm yy week no  \
# 3098    46.67   Standard  Atliq Exotica    Luxury     Mumbai  Jun 22    W 23
# 3099    60.00   Standard     Atliq City  Business  Hyderabad  Jun 22    W 23
# 3100    60.00   Standard      Atliq Bay    Luxury  Bangalore  Jun 22    W 23
# 3101    46.67   Standard   Atliq Palace  Business  Bangalore  Jun 22    W 23
# 3102    42.11   Standard   Atliq Grands    Luxury     Mumbai  Jun 22    W 23
#
#       day_type
# 3098  weekeday
# ...

# %%
df_june_22.groupby("city")["occ_pct"].mean().round(2).sort_values(ascending = False)
# Out:
# city
# Delhi        61.46
# Mumbai       57.79
# Hyderabad    57.69
# Bangalore    55.85
# Name: occ_pct, dtype: float64

# %%
df_august_22 = pd.read_csv("datasets/new_data_august.csv")

# %%
df_august_22.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_august_22.rename(columns = {"occ%": "occ_pct"}, inplace=True)
df_august_22.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ_pct'],
#       dtype='object')

# %%
df_august_22.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (9194, 13)

# %%
latest_df = pd.concat([df,df_august_22], axis = 0, ignore_index = True)
latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
# 9194        16559     01-Aug-22           RT1                   30      30.0
# 9195        19562     01-Aug-22           RT1                   21      30.0
# 9196        19563     01-Aug-22           RT1                   23      30.0
# 9197        19558     01-Aug-22           RT1                   30      40.0
# 9198        19560     01-Aug-22           RT1                   20      26.0
# 9199        17561     01-Aug-22           RT1                   18      26.0
# 9200        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class  property_name  category       city  mmm yy  \
# ...

# %%
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_bookings_all = pd.merge(df_bookings,df_hotels, on= "property_id")
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum().round(2)
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_date["date"] = df_date["date"].apply(lambda x : pd.to_datetime(x))
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_bookings_all["check_in_date"] = df_bookings_all["check_in_date"].apply(lambda x : pd.to_datetime(x))
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_bookings_all = pd.merge(df_bookings_all,df_date, left_on= "check_in_date" , right_on = "date")

# %%
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
# 3  May052216558RT14        16558     3/5/2022    2022-05-05      6/5/2022
# 4  May052216558RT15        16558     30-04-22    2022-05-05     10/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
# 3        2.0           RT1         tripster            3.0    Checked Out
# 4        4.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# ...

# %%
df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    389940912
# Jun 22    377191229
# May 22    408375641
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.rename(columns={'category': 'hotel_category'}, inplace = True)
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
# 3  May052216558RT14        16558     3/5/2022    2022-05-05      6/5/2022
# 4  May052216558RT15        16558     30-04-22    2022-05-05     10/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
# 3        2.0           RT1         tripster            3.0    Checked Out
# 4        4.0           RT1           others            4.0    Checked Out
#
# ...

# %%
df_bookings_all.groupby("hotel_category")["revenue_realized"].sum()
# Out:
# hotel_category
# Business    451950715
# Luxury      723557067
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.groupby("city")["ratings_given"].mean().round(2)
# Out:
# city
# Bangalore    3.40
# Delhi        3.78
# Hyderabad    3.66
# Mumbai       3.64
# Name: ratings_given, dtype: float64

# %%
df_bookings_all.groupby("booking_platform")["revenue_realized"].sum()
# Out:
# booking_platform
# direct offline     59298844
# direct online     117245053
# journey            71231599
# logtrip           129036321
# makeyourtrip      233132708
# others            480698244
# tripster           84865013
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.groupby("booking_platform")["revenue_realized"].sum().plot(
        kind = "pie", 
        autopct="%1.1f%%",   # Show percentage
        explode=[0.1] * df_bookings_all["booking_platform"].nunique(),  # Explode all slices equally
        shadow=True,
        ylabel = "",
        startangle = 140)
# Out:
# <Axes: >
